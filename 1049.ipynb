# %% [markdown]
# ![image.png](attachment:a36713fc-f58c-4c52-987a-9c86b7bd3398.png)

# %%
a= input()
b= input()
c= input()
animais = {
    'vertebrado':{
        'ave':{
            'carnivoro':'aguia',
            'onivoro':'pomba',
            
        },
        'mamifero':{
            'onivoro':'homem',
            'herbivoro':'vaca',
        }
    },
    'invertebrado':{
        'inseto':{
            'hematofago':'pulga',
            'herbivoro':'lagarta',
        },
        'anelideo':{
            'hematofago':'sanguessuga',
            'onivoro':'minhoca',
        }
    }
}
print(animais[a][b][c])
# Out:
#  vertebrado
#  ave
#  carnivoro
# aguia
