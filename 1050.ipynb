# %% [markdown]
# ![image.png](attachment:aad50f46-c5fe-4531-8c8a-6e5021db152b.png)

# %%
DDD = {
    61:'Brasilia',
    71:'Salvador',
    11:'Sao Paulo',
    21:'Rio de Janeiro',
    32:'Juiz de Fora',
    19:'Campinas',
    27:'Vitoria',
    31:'Belo Horizonte'
}
entrada = int(input())
print(DDD[entrada] if DDD.__contains__(entrada) else 'DDD nao cadastrado')
# Out:
#  61
# Brasilia

# %%
DDD.__contains__(9)
